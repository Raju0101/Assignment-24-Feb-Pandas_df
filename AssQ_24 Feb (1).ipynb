# %% [markdown]
# #  Assignment 24 Feb Pandas Assinmt-2

# %%
# Q1. List any five functions of the pandas library with execution.

# %%
# 1. read_csv() · 2. head() · 3. describe() · 4. memory_usage() · 5. astype() · 6. loc[:] · 7. to_datetime() · 8. value_counts(), 9. sort_values()

# %%
import pandas as pd
df = pd.read_csv("services.csv")

# %%
df.head(1)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
#
#           application_process  \
# 0  Walk in or apply by phone.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
#
#   interpretation_services                                           keywords  \
# 0                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
#
#   languages                             name required_documents service_areas  \
# 0       NaN  Fair Oaks Adult Activity Center                NaN         Colma
#
#    status wait_time website taxonomy_ids
# 0  active  No wait.     NaN          NaN
#
# ...

# %%
df.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
df.memory_usage()
# Out:
# Index                      128
# id                         184
# location_id                184
# program_id                 184
# accepted_payments          184
# alternate_name             184
# application_process        184
# audience                   184
# description                184
# eligibility                184
# email                      184
# fees                       184
# funding_sources            184
# interpretation_services    184
# keywords                   184
# languages                  184
# name                       184
# required_documents         184
# service_areas              184
# status                     184
# wait_time                  184
# website                    184
# taxonomy_ids               184
# dtype: int64

# %%
df.astype
# Out:
# <bound method NDFrame.astype of     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.sort_values('id')
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the 
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
import pandas as pd
df  = pd.read_excel("Practice in Python.xlsx")

# %%
df
# Out:
#     A   B    C
# 0   1   4    7
# 1   2   5    8
# 2   3   6    9
# 3  10  43   52
# 4  20  67   45
# 5  30  55   54
# 6  40  65   66
# 7  50   8   33
# 8  60  76  346

# %%
df1 = df.reindex([1,3,5,7,9,11,13])
df1
# Out:
#        A     B     C
# 1    2.0   5.0   8.0
# 3   10.0  43.0  52.0
# 5   30.0  55.0  54.0
# 7   50.0   8.0  33.0
# 9    NaN   NaN   NaN
# 11   NaN   NaN   NaN
# 13   NaN   NaN   NaN

# %%
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that 
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The 
# function should print the sum to the console.

# For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should 
# calculate and print the sum of the first three values, which is 60.

# %%
import pandas as pd
df = pd.read_excel("Practice in Python.xlsx")
df
# Out:
#    values
# 0      10
# 1      20
# 2      30
# 3      50
# 4      60

# %%
sum = df.iloc[0:3].sum()
sum
# Out:
# values    60
# dtype: int64

# %%
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
import pandas as pd

# %%
df = pd.read_excel("Practice in Python.xlsx")
df
# Out:
#                               Text
# 0                       I love you
# 1         I can not live without u
# 2  data science is the best topics

# %%
df['word_count'] = df['Text'].apply(lambda x : len(x.split()))

# %%
df
# Out:
#                               Text  word_count
# 0                       I love you           3
# 1         I can not live without u           6
# 2  data science is the best topics           6

# %%
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %%
# DataFrame.shape():-
# The shape of a DataFrame is a tuple of array dimensions that tells the number of rows and columns of a given DataFrame.

# DataFrame.size():-
# The size property will return the size of a pandas DataFrame, which is the exact number of data cells in your DataFrame

# %%
# Q6. Which function of pandas do we use to read an excel file?

# %%
# read () is use to read anexcel file in pandas
# import pandas as pd
# df = pd.read_excel("file.xlsx")

# %%
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email 
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column 
# 'Username' in df that contains only the username part of each email address.

# The username is the part of the email address that appears before the '@' symbol. For example, if the 
# email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your 
# function should extract the username from each email address and store it in the new 'Username' column.

# %%
import pandas as pd

# %%
df = pd.read_excel("Practice in Python.xlsx")
df
# Out:
#                  Email
# 0  rajuk9001@gmail.com
# 1  rahul6576@gmail.com
# 2   rinki765@gmail.com

# %%
df['new_column'] = df['Email'].str.split('@').str[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Email'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
email = "rajuk9001@gmail.com"
username = email[:email.index('@')]
print(username) # Output: rajuk9001
# Out:
# rajuk9001

# %%
df['C'] = df['A'] + df['B']

# %%
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects 
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The 
# function should return a new DataFrame that contains only the selected rows.

# For example, if df contains the following values:

   A   B   C

0  3   5   1

1  8   2   7

2  6   9   4

3  2   3   5

4  9   1   2

# %%
import pandas as pd

# %%
df = pd.read_excel("Practice in Python.xlsx")
df.head()
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
df1 = df.loc[(df['A'] > 5) & (df['B'] < 10)]
df1
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2
